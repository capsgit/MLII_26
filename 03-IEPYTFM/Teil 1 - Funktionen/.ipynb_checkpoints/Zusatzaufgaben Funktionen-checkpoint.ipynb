# %% [markdown]
# ## Aufgabe:
#
# Schreiben Sie eine Funktion die eine Zufallszahl generiert (Modul random). Die Zahl soll sich zwischen einem Mindesttwert und Maximalwert bewegen.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Zusatzaufgabe
#
# Die Funktion soll erweitert werden. Die Zufallszahl soll anhand einer Liste überprüft werden. Ist sie in der Liste soll so lange eine Zufallszahl gesucht werden bis eine gefunden wird, die nicht in der Liste steht.
# Diese Zufallszahl soll dann ausgegeben werden.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ## Aufgabe:
#
# Suchen sie sich einen beliebigen String. Diser soll in einer Funktion umgedreht werden. Schreiben sie ein entsprechendes Programm.
# Bsp.: Aus 'Hallo' wird nach der Bearbeitung 'ollaH'

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ## Aufgabe
#
# ### Sortieren 1
# Folgende Liste ist gegeben:
#
# <img src="img/liste1.png">
#
# Schreibe ein Programm das die Zahlen in aufsteigender Reihenfolge sortiert.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Sortieren 2
#
# Jetzt die Liste nach den Worten sortieren.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Sortieren 3
# Gegeben ist folgende Liste:
#
# <img src="img/liste2.png">
#
# Diese Liste bitte absteigend sortieren.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Vornamen sortieren
#
# Gegeben ist eine Liste mit Dictionaries, die einige Daten über Personen enthalten:
#
# <img src="img/liste3.png">
#
# Sortieren sie diese nach dem Vornamen.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Sortieren nach Zahlen
#
# Gegeben ist folgendes Dictionary:
#
# <image src="img/liste4.png">
#
# Sortieren sie die Zahlen aufsteigend.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Sortieren nach zwei Werten
#
# Gegen ist das folgende Dictionary:
#
# <image src="img/liste5.png">
#
# Sortieren sie dieses nach Vornamen und Alter.

# %%
Ihre Lösung hier!!!
