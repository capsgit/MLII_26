# %% [markdown]
# ## Aufgabe:
#
# Escriba una función que genera un número aleatorio (módulo aleatorio). El número debe moverse entre un valor mínimo y un valor máximo.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Zusatzaufgabe
#
# Se debe ampliar la función. Se debe comprobar el número aleatorio por medio de una lista. Si se busca un número aleatorio en la lista hasta que se encuentre uno que no esté en la misma. Este número aleatorio debe ser emitido.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ## Aufgabe:
#
# Búsquese cualquier cadena. Diser debe ser invertido en una función. Escriba un programa apropiado. Por ejemplo: 'Hola' se convierte en 'ollaH' después de editar

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ## Aufgabe
#
# ### Sortieren 1
# Se presenta la siguiente lista:
#
# <img src="img/liste1.png">
#
# Escribe un programa que ordene los números en orden ascendente.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Sortieren 2
#
# Ahora ordenar la lista según las palabras.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Sortieren 3
# La lista es la siguiente:
#
# <img src="img/liste2.png">
#
# Diese Liste bitte absteigend sortieren.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Vornamen sortieren
#
# Hay una lista de dictionaries que contienen algunos datos sobre personas:
#
# <img src="img/liste3.png">
#
# Sortieren sie diese nach dem Vornamen.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Sortieren nach Zahlen
#
# Este es el Dictionary:
#
# <image src="img/liste4.png">
#
# Ordenar los números ascendentemente.

# %%
Ihre Lösung hier!!!

# %% [markdown]
# ### Sortieren nach zwei Werten
#
# Contra el siguiente dictionary:
#
# <image src="img/liste5.png">
#
# Ordena esto por nombre y edad.

# %%
Ihre Lösung hier!!!
