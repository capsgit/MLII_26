# %% [markdown]
# ### Zusatzaufgabe
#
# Si en la parte 1 de este curso has resuelto la tarea de la máquina tragaperras, escríbela de tal manera que las funcionalidades se envuelvan significativamente en funciones.
#
# Falls nicht:
#
# Escriba el código para una máquina expendedora de bebidas.
#
# Se dice que esta máquina tiene varias bebidas para elegir, que pueden tener diferentes precios.
#
# Se ha creado un menú que, por ejemplo, podría ser así:
#
# ** Bebida -O- Mat*** 1 - Coca: 1.00 Euro 2 - Fanta: 0.00 Euro 3 - Sprite: 1.200 Euro 4 - Zumo: 1.10 Euro 5 - Agua: 0.80 Euro 6 - Red Bull: 300 Euro 0 - Terminar Por favor, seleccione una bebida: (1-6)
#
# Después de seleccionar la bebida, se pide al usuario que inserte una vez más monedas. La bebida sólo se emitirá cuando la cantidad se haya pagado por completo. Sólo entonces el usuario recibirá su bebida y el cambio posible.

# %%
# ihr Code hier!
