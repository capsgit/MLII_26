# %% [markdown]
# ### Zusatzaufgabe
#
# Falls Sie in Teil 1 dieses Kurses die Getränkeautomat-Aufgabe gelöst haben, schreiben Sie diese so um, das die Funktionalitäten sinnvoll in Funktionen aufgetreilt werden.
#
# Falls nicht:
#
# Schreiben Sie den Code für einen Getränkeautomaten.
#
# Dieser Automat soll mehrere Getränke zur Auswahl haben, die unter Umständen auch verschiedene Preise haben.
#
# Es soll ein Menü ausgegeben, welches beispielsweise so aussehen könnte:
#
# ** Getränk -O- Mat***
# 1 - Cola: 1.00 Euro
# 2 - Fanta: 1.00 Euro
# 3 - Sprite: 1.00 Euro
# 4 - Saft: 1.10 Euro
# 5 - Wasser: 0.80 Euro
# 6 - Red Bull: 3.00 Euro
# 0 - beenden
# Bitte wählen Sie ein Getränk: (1-6)
#
# Nach Auswahl des Getränks wird der Benutzer aufgefordert nacheinander Münzen einzuwerfen. Das Getränk wird erst dann ausgegeben, wenn der Betrag vollständig bezahlt ist. Erst dann bekommt der Benutzer sein Getränk und eventuelles Wechselgeld.

# %%
# ihr Code hier!
