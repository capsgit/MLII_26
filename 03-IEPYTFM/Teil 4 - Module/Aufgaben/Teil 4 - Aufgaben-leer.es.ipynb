# %% [markdown]
# # Aufgaben Teil 4
#
# ## Aufgabe 1: Erstellen eines Konvertierungsmoduls
#
# Objetivo: Cree un módulo converter.py que contenga funciones de conversión entre diferentes unidades (** conducción en Celsius**, **kilometro en millas**).
#
# Formel Umrechnung Fahrenheit in Celsius:
# $$ C = \frac{5}{9} \times (F - 32) $$
#
# Formel Kilometer in Meilen:
# $$ M = KM \times 0.621371 $$

# %% [markdown]
# Erstellen Sie eine konverter.py

# %%
# Ihr Code HIER!

# %% [markdown]
# El programa principal:

# %%
# Ihr Code HIER!

# %% [markdown]
# ## Aufgabe 2: Erstellen eines einfachen Statistikmoduls
#
# Objetivo: Escriba un módulo **estadistica.py** con el siguiente contenido:

# %%
# statistik.py

def mittelwert(*zahlen):
    return sum(zahlen) / len(zahlen)

def median(*zahlen):
    n = len(zahlen)
    sortiert = sorted(zahlen)
    mitte = n // 2
    if n % 2 == 0:
        return (sortiert[mitte - 1] + sortiert[mitte]) / 2
    else:
        return sortiert[mitte]

# %% [markdown]
# Escriba el programa principal que aplica estas funciones a la serie de números 1,2,3,4,5. ;-)

# %%
# Ihr Code HIER!

# %% [markdown]
# ## Aufgabe 3: Erstellen eines Textbearbeitungsmoduls
#
# **Objetivo**: Desarrolla un módulo **Editar texto.py** que ofrece funciones para la manipulación de texto frecuente, como convertir una cadena o contar palabras.

# %%
# Ihr Code HIER!

# %% [markdown]
# Importar los módulos en el **mainprogramm.py** y utilizar los métodos en un texto.

# %%
# Ihr Code HIER!

# %% [markdown]
# ## Aufgabe 4: Erstellen eines Geometriemoduls
# **Objetivo**: Escriba un módulo **geometría.py** que realice cálculos geométricos como el área de un círculo o la dimensión de un rectángulo.
#
# **geometrie.py**:

# %%
# Ihr Code HIER!

# %% [markdown]
# Hauptprogramm **hauptprogramm.py**:

# %%
# Ihr Code HIER!

# %% [markdown]
# <img style="float: center;" src="img/wbs-logo.jpg">
#
#
# ### Ilustraciones y fuentes
# https://de.wikipedia.org/wiki/Python_(Idioma de programación) El logotipo de Pythan es una marca registrada de la Fundación de Software de Pyothon Todos los logotipos publicados en este sitio web, así como marcas comerciales, productos y marcas registradas, son propiedad de sus respectivas empresas © WBS TRAINING AG • Todos los derechos reservados
#
# ### Nutzungsrechte:
# El uso de esta documentación está autorizado exclusivamente para fines de formación de WBS TRAINING AG. La transferencia a terceros, incluso en parte, así como la reproducción y difusión de todo tipo (procedimientos electrónicos y de otro tipo), incluidas las traducciones, sólo se permite con el consentimiento previo por escrito del titular del derecho.
#
# ### Herausgeber:
#
# WBS TRAINING AG
# Lorenzweg 5
# 12099 Berlin
#
# ### Haftungsausschluss:
# Todos los contenidos son correctos y están completamente investigados y compilados con el máximo cuidado para el documento de formación. Nos esforzamos por actualizar toda la información y los datos en curso. Sin embargo, pueden producirse errores (por ejemplo, desviaciones del hardware y del software descritos mediante actualizaciones a corto plazo) para que no podamos garantizar la plena conformidad, exactitud y actualidad. Los consejos de nuestros usuarios se siguen de forma coherente.
