# %% [markdown]
# <img style="float: right;" src="img/python.png">
#
# # Parte 2: Fecha y hora
#
# Datum und Zeitangaben werden in der Programmierung immer wieder verwendet. Es lohnt sich daher diese Funktionen einmal genauer zu betrachten.<br><br><br>

# %% [markdown]
# ## El módulo "time"
# El módulo Time contiene funciones de formato y procesamiento de fechas y fechas. Para muchos sistemas operativos, como Linux/ Unix, el **01. 01. 1970 00:00** se utiliza como punto cero para la hora. Se calcula el tiempo en segundos a partir de esa fecha. El módulo "time" debe ser importado antes de su uso. (Para más información sobre el módulo "tiempo" véase: https://docs.python.org/3/library/time.html

# %%
# Ihr Code HIER!

# %% [markdown]
# Es cierto que esta fecha es un poco difícil de leer. Afortunadamente, hay maneras más fáciles de trabajar con el tiempo.

# %% [markdown]
# ### Funktion strftime()
# La mejor información es la función **strftime() **. Esto requiere 2 parámetros:
# * Einen Formatierungsstring
# * un temporizador suministrado, por ejemplo, por **localtime()**
#
# Eine Dokumentation von strftime() finden Sie unter der folgenden Adresse:<br>
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes
# <br>

# %%
import time

print (time.strftime("Tag.Monat.Jahr: -----> %d.%m.%Y"))
print (time.strftime("Stunde:Minute:Sekunde: -----> %H:%M:%S"))
print (time.strftime("Im 12h-Format: -----> %I:%M:%S Uhr %p"))
print (time.strftime("Datum und Zeit: -----> %c"))
print (time.strftime("nur Datum: -----> %x, nur Zeit: -----> %X"))
print (time.strftime("Wochentag abgekürzt: -----> %a, ganz: -----> %A, Nr. (Sonntag=0): -----> %w"))
print (time.strftime("Monat abgekürzt: -----> %b, ganz: -----> %B"))
print (time.strftime("Tag des jahres: -----> %j"))
print (time.strftime("Woche des Jahres, Start bei Sonntag: -----> %U"))
print (time.strftime("Woche des Jahres, Start bei Montag: -----> %W"))
print (time.strftime("Zeitzone: -----> %Z"))
# Out:
# Tag.Monat.Jahr: -----> 08.01.2026
# Stunde:Minute:Sekunde: -----> 10:26:18
# Im 12h-Format: -----> 10:26:18 Uhr AM
# Datum und Zeit: -----> Thu Jan  8 10:26:18 2026
# nur Datum: -----> 01/08/26, nur Zeit: -----> 10:26:18
# Wochentag abgekürzt: -----> Thu, ganz: -----> Thursday, Nr. (Sonntag=0): -----> 4
# Monat abgekürzt: -----> Jan, ganz: -----> January
# Tag des jahres: -----> 008
# Woche des Jahres, Start bei Sonntag: -----> 01
# Woche des Jahres, Start bei Montag: -----> 01
# Zeitzone: -----> Mitteleuropäische Zeit

# %% [markdown]
# Para que los días se muestren en la lengua alemana, se puede insertar la siguiente línea:

# %%
import time

import locale
#nombre = clase.methode de esa clase()
z = time.time()

#
print("segundos (y milisegundos) que han pasado desde 01.01.1970 00:00am: ", z)


locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')

print(time.strftime("En español!!!!: -----> %A, %d. %B %Y", time.localtime(z)))
print(time.strftime("dia del año: -----> %j"))
# Out:
# segundos (y milisegundos) que han pasado desde 01.01.1970 00:00am:  1767864976.6014464
# En español!!!!: -----> jueves, 08. enero 2026
# dia del año: -----> 008

# %% [markdown]
# ### Contando con los tiempos
# Una vez más, una función siempre popular es esperar tiempo. **Se necesita el módulo **"datetime"**. Para obtener más información sobre **dateTime**, consulte: https: /docs. python. org/3/library/ datetiem. html

# %% [markdown]
# ¿Cuándo es Navidad?

# %%
from datetime import datetime

hoy = datetime.now()
hoy2 = datetime.today()
xmas = datetime(2026, 12, 24)

print(f"Weihnachten ist in {(xmas - hoy).days} Tagen.")
# Out:
# Weihnachten ist in 349 Tagen.

# %% [markdown]
# En el siguiente ejemplo, simplemente se toma el tiempo actual**, y **45 minutos** se cuenta con:

# %%
from datetime import datetime, timedelta

ahora = datetime.now()
mas_tarde = ahora + timedelta(minutes=45)

print(f"ahora son las {ahora.strftime('%H:%M:%S')}")
print(f"en 45 minutos seran las {mas_tarde.strftime('%H:%M:%S')}")
# Out:
# ahora son las 11:02:20
# en 45 minutos seran las 11:47:20

# %% [markdown]
# Por supuesto, el ejemplo anterior no es adecuado para una medición razonable del tiempo, ni para los archivos de registro, etc. El siguiente ejemplo muestra una manera de medir un cierto tiempo:

# %% [markdown]
# Una forma bastante incómoda pero muy flexible de calcular la duración es medir el tiempo necesario en segundos y luego convertirlo en horas y minutos. Para ello se requiere la **División de números completos** (véase el día 1):

# %%
from datetime import datetime, timedelta
from time import sleep

ahora = datetime.now()
print(f"ahora son las {ahora.strftime('%H:%M:%S')}")
mas_tarde = ahora + timedelta(minutes=45)

sleep(3)
ahora_mas_sleep = datetime.now()
tiempo_sleep = ahora_mas_sleep - ahora

print(f"ahora despues de {tiempo_sleep.seconds} segundos, son las {ahora_mas_sleep.strftime('%H:%M:%S')}")

print(f"en 45 minutos seran las {mas_tarde.strftime('%H:%M:%S')}")

#-------------------------------------------------------------------------------------
print("-----------------------------------------------------------------------------")
jetzt = datetime.now()  # Zeit jetzt wird genommen
print(jetzt.strftime("%H:%M:%S"))  # formatierte Zeitausgabe

sleep(3)  # Wartet 3 Sekunden

gleich = datetime.now()  # Zeit wird erneut genommen
print(gleich.strftime("%H:%M:%S"))  # formatierte Zeitausgabe

dauer = gleich - jetzt  # Dauer wird berechnet

print(f"Dauer: {dauer.seconds} Sekunden")  # Ausgabe der Sekunden (gerundet)
# Out:
# ahora son las 11:12:47
# ahora despues de3 segundos, son las 11:12:50
# en 45 minutos seran las 11:57:47
# -----------------------------------------------------------------------------
# 11:12:50
# 11:12:53
# Dauer: 3 Sekunden

# %%
from datetime import datetime
from time import sleep

jetzt = datetime.now()
print(jetzt)

sleep(2) # Wartezeit in Sekunden

gleich = datetime.now()
print(gleich)

dauer = gleich - jetzt

dauer_sek = dauer.total_seconds()
print("Dauer in Sekunden: ", dauer_sek)

# Stunden
stunden = dauer_sek // 3600
# verbleibende Sekunden
dauer_sek = dauer_sek - (stunden * 3600)
# Minuten
minuten = dauer_sek // 60  # Ganzzahlendivision
# übrig gebliebene Sekunden:
sekunden = dauer_sek - (minuten * 60)
# formatierte Ausgabe:
print('{:02}:{:02}:{:02}'.format(int(stunden), int(minuten), int(sekunden)))
# Out:
# 2026-01-08 11:10:20.648437
# 2026-01-08 11:10:22.648871
# Dauer in Sekunden:  2.000434
# 00:00:02

# %% [markdown]
# #### Zeitangabe aus String erstellen:

# %%
from datetime import datetime

t1 = "2019-12-24 18:00:00"  # Datum nach ISO-8601-Format (normaler String, nur formatiert halt)
dateobject_from_iso = datetime.fromisoformat(t1)
print("Ausgabe der Datetime-Objekte im Rohformat:")
print("Dateobject --------> ISO:", dateobject_from_iso)

t2 = "2019 01 11"

# mit "%Y %m %d" wird festgelegt, wie sich das Datum aus dem String zusammensetzt:
dateobject_from_str = datetime.strptime(t2, "%Y %m %d")
print("Dateobject -------> String:", dateobject_from_str)

print("Ausgabe der FORMATIERTEN Datetime-Objekte")
# Formatiert vom ISO-String:
print("ISO formatiert:", dateobject_from_iso.strftime("%d.%m.%Y"))

# oder vom String:
print(f"String formatiert: {dateobject_from_str:%d.%m.%Y}")
# Out:
# Ausgabe der Datetime-Objekte im Rohformat:
# Dateobject from ISO: 2019-12-24 18:00:00
# Dateobject from String: 2019-01-11 00:00:00
# Ausgabe der FORMATIERTEN Datetime-Objekte
# Dateobject from ISO formatiert: 24.12.2019
# Dateobject from String formatiert: 11.01.2019

# %% [markdown]
# ## Zeitgesteuerte Aufgaben
#
# Introducción al módulo schedule en Python
#
# El módulo schedule es una biblioteca sencilla e intuitiva para ejecutar funciones de Python con tiempo. Es especialmente adecuado para tareas de automatización pequeñas, como:
#
# * envío regular de correos electrónicos,
# * automatisiertes Daten-Backup,
# * periodisches Abrufen von API-Daten,
# * zeitlich gesteuerte Skriptaktionen.
#
# Beneficios obtenidos:
# * einfache Syntax,
# * keine komplexen Cronjobs notwendig,
# * bien adaptado para scripts y procesos de fondo simples.
#
# schedule planea una función (por ejemplo, ejecutar la función cada 10 minutos) y comprueba periódicamente en un bucle si esta tarea es necesaria.
#
# El módulo es puramente a nivel de Python y no utiliza servicios del sistema como el motor de tareas en Windows o cron en Linux.
#
# 🔧 Typische Einsatzbereiche
# Beispiel	Beschreibung
#
# * schedule.every(10).seconds	Alle 10 Sekunden
# * schedule.every().hour	Jede volle Stunde
# * schedule.every().day.at("08:00") Todos los días a las 8:00 horas
# schedule.every().monday.at("12:00") Todos los lunes a las 12:00

# %% [markdown]
# ### Ejecutar trabajo cada 10 segundos

# %%
import schedule
import time

def job():
    print("Job läuft:", time.strftime("%H:%M:%S"))
schedule.run_pending()
schedule.every(5).seconds.do(job) #se crea un trabajo/tarea, cada 5 segundos se llamara a la funcion "job()"

print("holis")
"""
while False:
    schedule.run_pending() #hay un "trabajo" en espera?
    time.sleep(2)
"""

import schedule
import time
import shutil

def job():
    total, used, free = shutil.disk_usage("/")
    print(f"Gesamt: {total // (2 ** 30)} GB, Frei: {free // (2 ** 30)} GB")

    if free / total < 0.1:
        print("⚠️ Weniger als 10 % frei!")

schedule.every(5).seconds.do(job)  # Eine Aufgabe wird erstellt, alle 5 Sekunden, Funktion "job" ausführen

#Endlos-Schleife:
while True:
    schedule.run_pending()  # Hier wird überprüft, ob ein Job "fällig" ist
    time.sleep(1)  # Wartet 1 Sekunde. Kann angepasst werden, abhängig davon, wie oft ein Job erwartet wird.
# Out:
# holis
# Job läuft: 12:12:03
# Gesamt: 99 GB, Frei: 8 GB
# ⚠️ Weniger als 10 % frei!
# Job läuft: 12:12:08
# Gesamt: 99 GB, Frei: 8 GB
# ⚠️ Weniger als 10 % frei!
# Job läuft: 12:12:13
# Gesamt: 99 GB, Frei: 8 GB
# ⚠️ Weniger als 10 % frei!
# Job läuft: 12:12:18
# Gesamt: 99 GB, Frei: 8 GB
# ⚠️ Weniger als 10 % frei!
# Job läuft: 12:12:23
# Gesamt: 99 GB, Frei: 8 GB
# ⚠️ Weniger als 10 % frei!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 32
#      30 while True:
#      31     schedule.run_pending()  # Hier wird überprüft, ob ein Job "fällig" ist
# ---> 32     time.sleep(1)  # Wartet 1 Sekunde. Kann angepasst werden, abhängig davon, wie oft ein Job erwartet wird.
#
# KeyboardInterrupt:

# %% [markdown]
# Declaración:
#
# * <code>schedule.run_pending()</code> prüft, ob ein geplanter Job fällig ist.
#
# * <code>time.sleep(1)</code> vermeidet zu hohe CPU-Auslastung.

# %% [markdown]
# ### Trabajo diario a una hora determinada

# %%
import schedule
import time
import mss, mss.tools


def bildschirmaufnahme():
    """Screenshot von einem bestimmten Monitor (1, 2, 3, ...)"""
    monitor = 1
    filename = "screenshot.png"

    with mss.mss() as sct:
        monitor = sct.monitors[monitor]
        screenshot = sct.grab(monitor)
        mss.tools.to_png(screenshot.rgb, screenshot.size, output=filename)

        print("Screenshot gespeichert unter: " + filename)

#aca!!!
schedule.every().day.at("08:00").do(bildschirmaufnahme)

# Endlos-Schleife:
while True:
    schedule.run_pending()  # Hier wird überprüft, ob ein Job "fällig" ist
    time.sleep(1)  # Wartet 1 Sekunde. Kann angepasst werden, abhängig davon, wie oft ein Job erwartet wird.

# %% [markdown]
# Ejecuta el trabajo todos los días a las 8:00 de la mañana. La hora debe estar en formato "HH:MM" (24h).

# %% [markdown]
# ### Lunes y miércoles a las 12:30 horas

# %%
import schedule
import time

def mittagsjob():
    print("Job am Montag und Mittwoch um 12:30")

schedule.every().monday.at("12:30").do(mittagsjob)
schedule.every().friday.at("12:30").do(mittagsjob)

while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# Job am Montag und Mittwoch um 12:30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 12
#      10 while True:
#      11     schedule.run_pending()
# ---> 12     time.sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# Posibles intervalos de tiempo
#
#    * schedule.every().second
#    * schedule.every().minute
#    * schedule.every().hour
#    * schedule.every().day
#    * schedule.every().monday (und andere Wochentage)
#
# Man kann auch schedule.every(5).minutes oder schedule.every(2).hours usw. verwenden.

# %% [markdown]
# <img style="float: center;" src="img/wbs-logo.jpg">
#
# Autor: Dirk Maric
# ### Ilustraciones y fuentes
# https://de.wikipedia.org/wiki/Python_(Idioma de programación) El logotipo de Pythan es una marca registrada de la Fundación de Software de Pyothon Todos los logotipos publicados en este sitio web, así como marcas comerciales, productos y marcas registradas, son propiedad de sus respectivas empresas © WBS TRAINING AG • Todos los derechos reservados
#
# ### Nutzungsrechte:
# El uso de esta documentación está autorizado exclusivamente para fines de formación de WBS TRAINING AG. La transferencia a terceros, incluso en parte, así como la reproducción y difusión de todo tipo (procedimientos electrónicos y de otro tipo), incluidas las traducciones, sólo se permite con el consentimiento previo por escrito del titular del derecho.
#
# ### Herausgeber:
#
# WBS TRAINING AG Lorenzweg 5 12099 Berlin Responsabilidad: Todos los contenidos están investigados y compilados con el máximo cuidado para la documentación de formación. Nos esforzamos por actualizar toda la información y los datos en curso. Sin embargo, pueden producirse errores (por ejemplo, desviaciones del hardware y del software descritos mediante actualizaciones a corto plazo), de modo que no podamos garantizar la total conformidad, exactitud y actualidad.
