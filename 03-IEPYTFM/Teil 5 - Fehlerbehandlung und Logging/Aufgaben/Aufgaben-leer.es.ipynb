# %% [markdown]
# # Aufgaben
#
# ## Aufgabe 1:
# Escriba una función que contenga un sencillo tratamiento de errores.

# %%
def pedir_numero(mensaje):
    while True:
        try:
            return float(input(mensaje))
        except ValueError:
            print("Entrada inválida. Ingresa un número.")

def dividir():
    while True:
        try:
            dividendo = pedir_numero("Ingresa un numero a dividir: ")
            divisor   = pedir_numero("Ingresa un numero divisor: ")

            resultado = dividendo / divisor
            print("Resultado:", resultado)
            break   # sale del loop si todo salió bien

        except ZeroDivisionError:
            print("No se puede dividir entre 0. Intenta nuevamente.")

    print("Fin del programa")

dividir()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 25
#      21             print("No se puede dividir entre 0. Intenta nuevamente.")
#      23     print("Fin del programa")
# ---> 25 dividir()
#
# Cell In[11], line 13, in dividir()
#      11 while True:
#      12     try:
# ---> 13         dividendo = pedir_numero("Ingresa un numero a dividir: ")
#      14         divisor   = pedir_numero("Ingresa un numero divisor: ")
#      16         resultado = dividendo / divisor
#
# Cell In[11], line 6, in pedir_numero(mensaje)
#       4 while True:
#       5     try:
# ----> 6         return float(input(mensaje))
#       7     except ValueError:
#       8         print("Entrada inválida. Ingresa un número.")
#
# File ~\Desktop\KursMaterial\.venv\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
# ...

# %% [markdown]
# ## Aufgabe 2:
# Cree su propio error y resolvalo.

# %%
# Ihr Code HIER!!!

# %% [markdown]
# ## Aufgabe 3: Grundlegendes Logging
#
# Schreiben Sie ein Python-Skript, das:
#
# - Crea un objeto de registro llamado "basicLogger."
# - Este objeto de registro está configurado para emitir mensajes de registro en la consola.
# - Varios mensajes de registro con diferentes grados (INFO, ADVERTENCIA, ERROR).
#
# Tenga en cuenta el uso de la biblioteca estándar de Python logging.

# %%
# Ihr Code HIER!!!

# %% [markdown]
# ### Tarea 4: Logging con diferentes niveles de registro
#
# Erstellen Sie ein Python-Skript, das:
#
# - Crea un objeto de registro llamado 'levelLogger'.
# - Configura dos manipuladores: uno para la salida de logs en la consola y otro para la escritura en un archivo.
# - El manipulador de la consola solo emite mensajes de ADVERTENCIA y ERROR y el manejador de archivos todos los niveles de registro.
#
# Experimente con varios mensajes de registro y compruebe los gastos.

# %%
# Ihr Code HIER!!!

# %% [markdown]
# ## Tarea 3: Logging con un formato personalizado
#
# Entwickeln Sie ein Python-Skript, das:
#
# - Crea un objeto de registro llamado 'formatLogger'.
# - Añade un manipulador que escribe mensajes de registro en un archivo.
# - Utiliza un formato de registro personalizado que contiene al menos un sello de tiempo, un nivel de registro y un mensaje.
#
# Pruebe el objeto de registro con varios mensajes y compruebe el formato en el archivo de registro.
#
# Estas tareas le ayudarán a comprender los fundamentos del registro en Python y a familiarizarse con las técnicas más avanzadas.

# %%
# Ihr Code HIER!!!

# %% [markdown]
# <img style="float: center;" src="img/wbs-logo.jpg">
#
#
# ### Ilustraciones y fuentes
# https://de.wikipedia.org/wiki/Python_(Idioma de programación) El logotipo de Pythan es una marca registrada de la Fundación de Software de Pyothon Todos los logotipos publicados en este sitio web, así como marcas comerciales, productos y marcas registradas, son propiedad de sus respectivas empresas © WBS TRAINING AG • Todos los derechos reservados
#
# ### Nutzungsrechte:
# El uso de esta documentación está autorizado exclusivamente para fines de formación de WBS TRAINING AG. La transferencia a terceros, incluso en parte, así como la reproducción y difusión de todo tipo (procedimientos electrónicos y de otro tipo), incluidas las traducciones, sólo se permite con el consentimiento previo por escrito del titular del derecho.
#
# ### Herausgeber:
#
# WBS TRAINING AG
# Lorenzweg 5
# 12099 Berlin
#
# ### Haftungsausschluss:
# Todos los contenidos son correctos y están completamente investigados y compilados con el máximo cuidado para el documento de formación. Nos esforzamos por actualizar toda la información y los datos en curso. Sin embargo, pueden producirse errores (por ejemplo, desviaciones del hardware y del software descritos mediante actualizaciones a corto plazo) para que no podamos garantizar la plena conformidad, exactitud y actualidad. Los consejos de nuestros usuarios se siguen de forma coherente.
