# %% [markdown]
# # Aufgaben Teil 1
#
# ## Aufgabe 1:
# <br>
# Bitte geben Sie die Zeichenkette Hallo Welt! aus.

# %%
print("Hallo Welt")
print("---------------------------")
# Out:
# Hallo Welt

# %% [markdown]
# ## Aufgabe 2:
# Was bedeuten die Datentypen **String**, **Float**, **Integer**, **Bool**? Erleutern Sie bitte die einzelnen Begriffe:

# %%
### String
#Ein String ist ein Datentyp, der Text darstellt. Strings bestehen aus Zeichen
#(Buchstaben, Zahlen oder Sonderzeichen) und werden in Anführungszeichen geschrieben.

#Beispiel:
name = 'Carlos'

#---------------------------------------------------------------

### Integer
#Ein Integer ist eine ganze Zahl ohne Dezimalstellen. Er kann positiv, negativ oder null sein.

#Beispiel:
zahl = -10

#---------------------------------------------------------------

### Float
#Ein Float ist eine Zahl mit Dezimalstellen. Er wird verwendet, wenn genauere
#Berechnungen notwendig sind.

#Beispiel:
preis = 3.14

#---------------------------------------------------------------

### Bool
#Ein Bool (Boolean) ist ein Datentyp mit nur zwei möglichen Werten: True oder False.
#Er wird häufig für Bedingungen und Vergleiche verwendet.

#Beispiel:
ist_volljaehrig = False

#---------------------------------------------------------------

### Beispiele:
string = "string"
float = 3.5
integer = 12
boolean = True
print("---------------------------")

# %% [markdown]
# ## Aufgabe 3:
# Bitte Lösen Sie mit Hilfe von Python die Matheaufgaben meiner Tochter:
# 1. 21 geteilt durch 3
# 2. 8 hoch 2
# 3. 23 mal 5
# 4. 20 plus 22
# 5. der Rest von 21 geteilt durch 2

# %%
# 21 geteilt durch 3
print(21 / 3)
# Out:
# 7.0

# %%
# 8 hoch 2
print(8 ** 2)

# %%
# 23 mal 5
print(23 * 5)

# %%
# 20 plus 22
print(20 + 22)

# %%
print(21 / 3)
print(8 ** 2)
print(23 * 5)
print(20 + 22)
print("---------------------------")
# Out:
# 7.0
# 64
# 115
# 42

# %% [markdown]
# ## Aufgabe 4:
# Bewerten Sie mit Python folgende Aussagen:
# 1. Ist die Zahl 5 kleiner als 10
# 2. Ist die Zahl 7 größer als 8
# 3. Ist die Zahl 8 ungleich 9

# %%
# Ist die Zahl 5 kleiner als 10
print(5 < 10)
# Out:
# True

# %%
# Ist die Zahl 7 größer als 8
print(7 > 8)
# Out:
# False

# %%
# Ist die Zahl 8 ungleich 9
print(8 == 9)
print("---------------------------")
# Out:
# False

# %% [markdown]
# ## Aufgabe 5:
# Füllen Sie Variablen **var1** mit dem Wert **30** und die Variable **var2** mit den Wert **23**.
# Danach führen Sie bitte die folgenden Rechenoperationen aus, und geben Sie den Rechenweg
# und das Ergebnis mit **print()** aus.
# * var1 - var2
# * var2 + var1
# * var2 * var1
#
# Erforderliche Ausgabe:
# ![Grafig:Aufgabe4](img/aufgabe4.jpg)

# %%
var1 = 30
var2 = 23

print(f"{var1} minus {var2} ergibt {var1 - var2}")
print(f"Die Summe von {var2} und {var1} ist {var2 + var1}")
print(f"{var2} mal {var1} ergibt {var2 * var1}")
print("---------------------------")
# Out:
# 30 minus 23 ergibt 7
# Die Summe von 23 und 30 ist 53
# 23 mal 30 ergibt 690

# %% [markdown]
# ## Aufgabe 6:
# Vorgegebene Variablen kann jeder. Bitte lassen Sie den Benutzer die Inhalte er Variablen wählen.
# Die Ausgabe soll dabei Aufgabe 5 entsprechen.<br><br>
# **Tipp:**
# Denken Sie daran, das die Variablen aus input() standardmäßig als String angenommen werden.
# Vor der Berechnung sollten diese in eine Fließkommazahl umgewandelt werden.

# %%
var1 = int(input("geben Sie bitte ein (ganze) Zahl ein: "))
var2 = int(input("geben Sie bitte noch ein zweite (ganze) Zahl ein: "))

print("-" * 30)
print(f"var1: {var1} || var2: {var2}".center(30))
print("-" * 30)
print(f"{var1} minus {var2} ergibt {var1 - var2}")
print(f"Die Summe von {var2} und {var1} ist {var2 + var1}")
print(f"{var2} mal {var1} ergibt {var2 * var1}")
print("---------------------------")
# Out:
# ------------------------------
#      var1: 15 || var2: 4
# ------------------------------
# 15 minus 4 ergibt 11
# Die Summe von 4 und 15 ist 19
# 4 mal 15 ergibt 60

# %% [markdown]
# ## Aufgabe 7:
#
# Speichern Sie die Zeichenkette **"Hallo Welt!"** in eine Variable und geben Sie anstatt **"Hallo Welt!"**, **"Welt! Hallo"** aus.

# %%
var1 = "Hallo Welt"
split = var1.split()
reverse = split[::-1]
res1 = " ".join(reverse)
print("R1: ", res1)
#-----------------------------------------

res2 = " ".join(var1.split()[::-1])
print("R2: ",res2)
print("---------------------------")
# Out:
# R1:  Welt Hallo
# R2:  Welt Hallo

# %% [markdown]
# ## Aufgabe 8:
# Wieviel Zeichen hat der Name der walisischen Stadt **"Llanfairpwllgwyngyllgogerychwyrndrobwllllantysiliogogogoch"**. Schreiben Sie eine Zeile Code, die das für Sie heraus findet.

# %%
var1 = "Llanfairpwllgwyngyllgogerychwyrndrobwllllantysiliogogogoch"
print(len(var1))
print("---------------------------")
# Out:
# 58

# %% [markdown]
# ## Aufgabe 9:
# Wenn man als Programmierer Nachts viel programmiert, kann es natürlich sein, das man morgens ein wenig länger schläft.
# Kommt das öfter vor, gehen einen schnell mal die Ausreden aus.
# <br>
# Um dieses Problem zu lösen, programmieren Sie bitte einen **Ausredengenerator**.
# <br>
# Dazu sammel sie einige Ausreden in variablen, und geben diese Zufällig aus. Da Variablen nicht mit Zahlen anfangen anfangen dürfen, müssen Sie sich etwas einfallen lassen, wie Sie sich diese Variable zusammen setzen.
#
# **Tipp:**
# random() hat eine Funktion, die sich **Choice** nennt. (https://docs.python.org/3/library/random.html)
# Man kann sich eine Liste erstellen, zum Beispiel ausreden = ausrede1, ausrede2, ausrede3, aus welcher dann eine
# Auswahl getroffen wird.

# %%
import random

excusa1= "mi abuela esta enferma"
excusa2= "mi perro se comio mis llaves"
excusa3= "no sabia"
excusa4= "eso no lo vimos en el curso"
excusa5= "mi celular se murio"
excusa6= "hubo un atasco (de cobijas)"
excusa7= "el tram no paso"
excusa8= "por culpa de los migrantes"

excusas = [excusa1, excusa2, excusa3, excusa4, excusa5, excusa6, excusa7, excusa8]

print(random.choice(excusas))
print("---------------------------")
# Out:
# mi perro se comio mis llaves

# %% [markdown]
# ## Aufgabe 10:
# Berechne die Fläche eines Rechtecks mit den Seiten a und b
# Die Seitenlängen sollen durch User-input erhoben werden.
# Die eingebenen Werte sollen Integer sein (Ganzzahlen).
#
# Berechne die Fläche und print das Ergebnis auf stdout.
#
# EVA
# Eingabe - Vearbeitung - Ausgabe

# %%
#Eingabe
a_side = int(input("geben Sie bitte die Rechtecks Basis (ganzZahl) ein: "))
b_side = int(input("geben Sie bitte noch die Rechtecks Höhe (ganzZahl) ein: "))

#Verarbeitung
area = a_side * b_side

#Ausgabe
print(f"Die Fläche eines Rechtecks mit eine Basis von {a_side}m und einer Höhe von {b_side}m ist: {area}m²")
print("---------------------------")
# Out:
# Die Fläche eines Rechtecks mit eine Basis von 15m und einer Höhe von 15m ist: 225m²

# %% [markdown]
# ## Aufgabe 11:
#
# Anhalteweg:
#
# Es gibt folgende Faustformeln zur Berechnung von Anhaltewegen:
#
# Reaktionsweg (in Metern) = (Geschwindigkeit (in km/h) geteilt durch 10) mal 3
#
# Bremsweg (in Metern) = (Geschwindigkeit (in km/h) geteilt durch 10) mal (Geschwindigkeit (in km/h) geteilt durch 10)
#
# Anhalteweg (in Metern) = Reaktionsweg plus Bremsweg
#
# Eingabe: km/h (via input-funktion)
#
# Gebe den Reaktionsweg, den Bremsweg und den Anhalteweg
# entsprechend der km/h aus. Hinweis: 124.4 ist ein gültiger Eingabewert.

# %%
geschwindigkeit = float(input("Gebe eine Geschwindigkeit (in km/h) ein: "))

reaktionsweg = (geschwindigkeit / 10) * 3
bremsweg = (geschwindigkeit / 10) ** 2
anhalteweg = reaktionsweg + bremsweg

print(f"Geschwindigkeit: {geschwindigkeit:.2f} km/h")
print()
print(f"Reaktionsweg: {reaktionsweg:.2f} m")
print(f"Bremsweg: {bremsweg:.2f} m")
print(f"Anhalteweg: {anhalteweg:.2f} m")
print("---------------------------")
# Out:
# Geschwindigkeit: 35.00 km/h
#
# Reaktionsweg: 10.50 m
# Bremsweg: 12.25 m
# Anhalteweg: 22.75 m

# %% [markdown]
# ## Aufgabe 12:
#
# Rechnen Sie die angegebenen Minuten in Tage, Stunden und Minuten um
# nutzen Sie dazu floordiv und modulo.
#
#
# MINUTES_DAY = 24 * 60 # 1440
#
#
# Wieviele Tage sind 3434 Minuten?
# Wieviele Stunden und Minuten bleiben dann noch übrig?
#
# Beispiel
#
# minuten = 3434
#
# sind 2 Tage, 9 Stunden und 14 Minuten

# %%
total_minuten = int(input("geben Sie die Anzahl von Minuten um in Tagen berechnen zu werden: "))

tage = total_minuten // 1440
minuten_ubrig = total_minuten % 1440

stunden = minuten_ubrig // 60
minuten = minuten_ubrig % 60

print(f"{total_minuten} Minuten entsprechen:")
print(f"{tage} Tage, {stunden} Stunden und {minuten} Minuten")
print("---------------------------")
# Out:
# 18795 Minuten entsprechen:
# 13 Tage, 1 Stunden und 15 Minuten
# ---------------------------

# %% [markdown]
# ## Aufgabe 13
#
# Der optimale Puls bei Ausdauersportarten hängt vom Alter ab. Er lässt sich
# mit der Formel Puls = 165 - 0.75 * Alter bestimmen.
#
# So ist der optimale Puls für 18 Jahre 151
# Schreibe ein Programm, das folgenden Dialog ermöglicht:
#
# Alter: über input einzugeben
# Ausgabe: optimaler Puls

# %%
alter = int(input("geben Sie ihre Älter in Jahren ein: "))

optimale_puls = int(165 - 0.75 * alter)

print(f"Der optimale Puls für jemand der {alter} Jahre alt ist, liegt bei: {optimale_puls} pro Minute")
print("---------------------------")
# Out:
# Der optimale Puls für jemand der 38 Jahre alt ist, liegt bei: 136 pro Minute
# ---------------------------

# %% [markdown]
# <img style="float: center;" src="img/wbs-logo.jpg">
#
#
# ### Abbildungs- und Quellenverzeichnis
# https://de.wikipedia.org/wiki/Python_(Programmiersprache)
# Das Python Logo ist ein eingetragenes Warenzeichen der Python Software Foundation
# Alle auf dieser Website veröffentlichten Logos sowie Marken-, Produkt- und Warenzeichen sind Eigentum der jeweiligen Unternehmen
# © WBS TRAINING AG – Alle Rechte vorbehalten
#
# ### Nutzungsrechte:
# Die Nutzung dieser Dokumentation ist ausschließlich für Schulungszwecke der WBS TRAINING AG gestattet. Eine Weitergabe an Dritte, auch auszugsweise, sowie Vervielfältigungen und Verbreitungen aller Art (elektronische und andere Verfahren) inklusive Übersetzungen sind nur mit vorheriger schriftlicher Zustimmung des Rechtinhabers gestattet. Zuwiderhandlungen verpflichten zu Schadenersatz.
#
# ### Herausgeber:
#
# WBS TRAINING AG
# Lorenzweg 5
# 12099 Berlin
#
# ### Haftungsausschluss:
# Alle Inhalte sind nach bestem Wissen korrekt und vollständig recherchiert und mit größtmöglicher Sorgfalt für die Schulungsunterlage zusammengestellt. Wir sind um die laufende Aktualisierung aller Informationen und Daten bemüht. Dennoch können Fehler (z.B. Abweichungen zur beschriebenen Hard- und Software durch kurzfristige Updates) auftreten, sodass wir für die vollständige Übereinstimmung, Richtigkeit und Aktualität keine Gewähr übernehmen. Hinweise unserer Nutzer werden konsequent weiterverfolgt.
