# %% [markdown]
# ### Zusatzaufgabe Passwortgenerator
# Schreiben Sie einen Passwortgenerator, der eine Zeichenkette mit den String-Methoden ascii_lowercase, string.ascii_uppercase, string.punctuation string.digits. Die Passwortlänge soll in einer Variable gespeichert werden. Jedes Zeichen soll einzeln auf dem Zeichenpool genommen werden. Am Ende soll ein String mit entsprechender Länge ausgegeben werden. Nutzen Sie dazu eine while-Schleife.

# %%
# Ihr Code HIER
