# %% [markdown]
# ### Zusatzaufgabe Passwortgenerator
# Escriba un generador de contraseñas que tenga una cadena con los métodos de cadena ascii_lowercase, string.ascii _uppercase , stering. puncitation string . digits. La longitud de la contraseña debe guardarse en una variable. Cada carácter debe ser tomado individualmente en el grupo de caracteres. Al final, se debe escribir una cadena de longitud equivalente. Utilice un bucle while para ello.

# %%
# Ihr Code HIER
