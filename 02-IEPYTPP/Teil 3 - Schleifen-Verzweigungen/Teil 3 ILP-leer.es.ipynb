# %% [markdown]
# # Teil ILP
#
# ## Wichtig
#
# <br> Erinnern Sie sich an das Beispiel von gestern?
# <br> Heute haben Sie gelernt, wie sie Abfragen erstellen.
# <br> Lassen Sie uns dieses Wissen einmal auf die Aufgabe von gestern anwenden.

# %% [markdown]
# ## Aufgabe 1:
# <br> Fügen Sie eine Abfrage ein, die sicherstellt, dass Werte von über 50 zu einer Fehlermeldung führt.

# %%
# Ihr Code HIER!

# %% [markdown]
# ## Aufgabe 2:
# Se ha recibido el encargo de escribir un programa que permita leer un número variable de notas y calcular el corte de notas de P1 y asegurarse de que solo se introduzcan números enteros que estén entre 1 y 6 P2.

# %%
# Ihr Code HIER!
