# %% [markdown]
# # Aufgaben
#
# ## Aufgabe 1:
# Por favor, cree una lista de sus animales favoritos (mínimo 5). Deje que esta lista interactúe con un bucle **for**.

# %%
#Ihre Antwort HIER

# %% [markdown]
# ## Aufgabe 2:
# Amplíe el programa para indicar la cantidad de la lista.

# %%
#Ihre Antwort HIER

# %% [markdown]
# ## Aufgabe 3:
# Escriba sólo las entradas 2 y 5 de esta lista.

# %%
#Ihre Antwort HIER

# %% [markdown]
# ## Aufgabe 4:
# Aceptar P0 Tome la lista de la tarea 1 y duplique la lista. A continuación, introduzca ais (iterada).

# %%
#Ihre Antwort HIER

# %% [markdown]
# ## Aufgabe 5:
# Quítese la lista de la tarea 1 y cambie el segundo animal por un pollo.

# %%
#Ihre Antwort HIER

# %% [markdown]
# ## Aufgabe 6:
# En el caso de los cerdos criados para la producción de leche, el número de identificación del aditivo para la alimentación animal será el siguiente:

# %%
#Ihre Antwort HIER

# %% [markdown]
# ## Aufgabe 7:
# P0 de la lista Ordenar la lista:

# %%
#Ihre Antwort HIER

# %% [markdown]
# ## Aufgabe 8:
# •P0 • Cambiar la lista de forma manual a un tubo y escríbela:

# %%
#Ihre Antwort HIER

# %% [markdown]
# ## Aufgabe 9 (schwer):
# Escriba un pequeño programa de aprendizaje de Inglés en el que se emita un diccionario y se pida la traducción de la palabra correspondiente. La respuesta debe ser evaluada (correcto o incorrecto).
#
# **Sugerencia:** La función **list()** podría ayudarle.

# %%
#Ihre Antwort HIER

# %% [markdown]
# <img style="float: center;" src="img/wbs-logo.jpg">
#
#
# ### Ilustraciones y fuentes
# https://de.wikipedia.org/wiki/Python_(Idioma de programación) El logotipo de Pythan es una marca registrada de la Fundación de Software de Pyothon Todos los logotipos publicados en este sitio web, así como marcas comerciales, productos y marcas registradas, son propiedad de sus respectivas empresas © WBS TRAINING AG • Todos los derechos reservados
#
# ### Nutzungsrechte:
# El uso de esta documentación está autorizado exclusivamente para fines de formación de WBS TRAINING AG. La transferencia a terceros, incluso en parte, así como la reproducción y difusión de todo tipo (procedimientos electrónicos y de otro tipo), incluidas las traducciones, sólo se permite con el consentimiento previo por escrito del titular del derecho.
#
# ### Herausgeber:
#
# WBS TRAINING AG
# Lorenzweg 5
# 12099 Berlin
#
# ### Haftungsausschluss:
# Todos los contenidos son correctos y están completamente investigados y compilados con el máximo cuidado para el documento de formación. Nos esforzamos por actualizar toda la información y los datos en curso. Sin embargo, pueden producirse errores (por ejemplo, desviaciones del hardware y del software descritos mediante actualizaciones a corto plazo) para que no podamos garantizar la plena conformidad, exactitud y actualidad. Los consejos de nuestros usuarios se siguen de forma coherente.
