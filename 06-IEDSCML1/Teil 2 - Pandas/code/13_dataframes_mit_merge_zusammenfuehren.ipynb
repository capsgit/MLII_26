# %% [markdown]
# # Dataframes mit Merge über gemeinse Spaltennamen zufammenführen
#
# die `Merge`-Methode bietet alle nötigen Join-Methoden an, um Dataframes zusammenzuführen. Sie ist mächtiger als die einfachere `Concat`-Methode aus dem Kapitel davor.
#
# die Merge-Methode erwartet einen linken Dataframe `left`, einen rechten DataFrame `right`, die Angabe der gewüschnter `Join`-Operation und mit `on` die Angabe, auf welcher Spalte bzw. ob auf den Indizies zusammengeführt werden soll.
#
# Grundsätzlich ist es eine gute Idee, Merge zu nutzen, wenn man auf Spaltenbasis zusammenführen will. Für das Zusammenführen auf der Indexmenge gibt es noch die Methode `join`.
#
#
# ## Beispiel
# Wir haben zwei DataFrames. `df_left` ist das  linke Dataframe, `df_right` ist das rechte DataFrame. Beide Dataframes teilen eine Spalte gleichen Namens, nämlich `motor`. Wir wollen dieses Dataframe jetzt zu einem Dataframe verbinden und nutzen dazu als gemeinsame Spalte `motor`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df_left = pd.DataFrame({
    "motor": ["A1", "A2", "A3", "A4"],
    "acc": [133, 132, 145, 111],
})


df_right = pd.DataFrame({
    "motor": ["A1", "A2", "A3", "A4"],
    "max": [233, 98, 241, 198],
})

display(df_left)
display(df_right)
# Out:
#   motor  acc
# 0    A1  133
# 1    A2  132
# 2    A3  145
# 3    A4  111
#   motor  max
# 0    A1  233
# 1    A2   98
# 2    A3  241
# 3    A4  198

# %%
# mit dem on-Keyword wird der Spaltenname angegeben, der in beiden DF gleich ist
df_merged = pd.merge(df_left, df_right, on="motor")
display(df_merged)
# Out:
#   motor  acc  max
# 0    A1  133  233
# 1    A2  132   98
# 2    A3  145  241
# 3    A4  111  198

# %% [markdown]
# ## Beispiel mit unterschiedlichen Keys
# Bei unterschiedlichen Spaltenwerten gehen Daten verloren

# %%
df_left2 = pd.DataFrame({
    "motor": ["A1", "A2", "A3", "A5"],
    "acc": [133, 132, 145, 111],
})


df_right2 = pd.DataFrame({
    "motor": ["A1", "A2", "A3", "A4"],
    "max": [233, 98, 241, 198],
})

df_merge_2 = pd.merge(df_left2, df_right2, on="motor") # inner join
display(df_merge_2)
# Out:
#   motor  acc  max
# 0    A1  133  233
# 1    A2  132   98
# 2    A3  145  241

# %% [markdown]
# ### Left Join, linke Spalte bleibt ganz erhalten
# resultiert natürlich in NaN-Werten für die fehlende Zeile

# %%
# Left join on motor
df_merged_left = pd.merge(df_left, df_right, on="motor", how="left")
display(df_merged_left)
# Out:
#   motor  acc  max
# 0    A1  133  233
# 1    A2  132   98
# 2    A3  145  241
# 3    A4  111  198

# %% [markdown]
# ### Outer Join, beide Spalten bleiben erhalten
# resultiert natürlich in NaN-Werten für die fehlende Zeile

# %%
# right join on motor
df_merged_right = pd.merge(df_left, df_right, on="motor", how="right")
display(df_merged_right)
# Out:
#   motor  acc  max
# 0    A1  133  233
# 1    A2  132   98
# 2    A3  145  241
# 3    A4  111  198

# %% [markdown]
# # Aufgabe: Bevölkerungszahlen für verschiedene Länder
#
# Führe die beiden Dataframes zusammen und berechne die Bevölkerungsdichte pro Land

# %%
import pandas as pd

# Bevölkerungszahlen für verschiedene Länder
data_population = {
    "Land": ["Deutschland", "Frankreich", "Italien", "Spanien"],
    "Bevölkerung": [83000000, 67000000, 60000000, 47000000]
}
df_population = pd.DataFrame(data_population)

# Flächenangaben für verschiedene Länder (in km²)
data_area = {
    "Land": ["Deutschland", "Frankreich", "Italien", "Spanien"],
    "Fläche_km2": [357386, 551695, 301340, 505992]
}
df_area = pd.DataFrame(data_area)

# Führe die Tabellen zusammen
df_merged = pd.merge(df_population, df_area, on="Land")

# Berechne die Bevölkerungsdichte (Einwohner pro km²)
df_merged["km2 x P"] = (df_merged["Bevölkerung"] / df_merged["Fläche_km2"]).round(2)

# style
sty = (
    df_merged.style
        .hide(axis="index")
        .format({
            "Bevölkerung": "{:,.0f}",
            "Fläche_km2": "{:,.0f}",
            "km2 x P": "{:,.2f}",
        })
)



# Ausgabe des Ergebnisses
print("Zusammengeführte Tabelle mit Bevölkerungsdichte:")
display(sty)
# Out:
# Zusammengeführte Tabelle mit Bevölkerungsdichte:
# <style type="text/css">
# </style>
# <table id="T_eba1c">
#   <thead>
#     <tr>
#       <th id="T_eba1c_level0_col0" class="col_heading level0 col0" >Land</th>
#       <th id="T_eba1c_level0_col1" class="col_heading level0 col1" >Bevölkerung</th>
#       <th id="T_eba1c_level0_col2" class="col_heading level0 col2" >Fläche_km2</th>
#       <th id="T_eba1c_level0_col3" class="col_heading level0 col3" >km2 x P</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eba1c_row0_col0" class="data row0 col0" >Deutschland</td>
#       <td id="T_eba1c_row0_col1" class="data row0 col1" >83,000,000</td>
#       <td id="T_eba1c_row0_col2" class="data row0 col2" >357,386</td>
#       <td id="T_eba1c_row0_col3" class="data row0 col3" >232.24</td>
#     </tr>
#     <tr>
#       <td id="T_eba1c_row1_col0" class="data row1 col0" >Frankreich</td>
#       <td id="T_eba1c_row1_col1" class="data row1 col1" >67,000,000</td>
#       <td id="T_eba1c_row1_col2" class="data row1 col2" >551,695</td>
#       <td id="T_eba1c_row1_col3" class="data row1 col3" >121.44</td>
#     </tr>
#     <tr>
#       <td id="T_eba1c_row2_col0" class="data row2 col0" >Italien</td>
#       <td id="T_eba1c_row2_col1" class="data row2 col1" >60,000,000</td>
#       <td id="T_eba1c_row2_col2" class="data row2 col2" >301,340</td>
#       <td id="T_eba1c_row2_col3" class="data row2 col3" >199.11</td>
#     </tr>
#     <tr>
#       <td id="T_eba1c_row3_col0" class="data row3 col0" >Spanien</td>
#       <td id="T_eba1c_row3_col1" class="data row3 col1" >47,000,000</td>
#       <td id="T_eba1c_row3_col2" class="data row3 col2" >505,992</td>
#       <td id="T_eba1c_row3_col3" class="data row3 col3" >92.89</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Erwartete Ausgabe**
#
# | Land        | Bevölkerung | Fläche (km²) | Bevölkerungsdichte (Einwohner/km²) |
# |-------------|-------------|--------------|----------------------------------|
# | Deutschland | 83,000,000  | 357,386      | 232.25                           |
# | Frankreich  | 67,000,000  | 551,695      | 121.46                           |
# | Italien     | 60,000,000  | 301,340      | 199.12                           |
# | Spanien     | 47,000,000  | 505,992      | 92.91                            |
#
# ---
