# %% [markdown]
# # Aufgaben
#
# ## Aufgabe 1:
#
# Amplíe su programa para el catálogo de productos con las siguientes funciones:
#
# - Produktliste anzeigen lassen
# - Produktdaten aktualisieren nach ID (Produkt ID)
# - Eliminar producto

# %%
# Out:
# Warenkatalog
# 1 - Produktliste anzeigen
# 2 - Produkt aktualisieren (nach ID)
# 3 - Produkt löschen (nach ID)
# e - Ende
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 181
#     178             print("❌ Opción inválida.")
#     180 if __name__ == "__main__":
# --> 181     menu()
#
# Cell In[3], line 137, in menu()
#     134 print("3 - Produkt löschen (nach ID)")
#     135 print("e - Ende")
# --> 137 choice = input("Auswahl: ").strip().lower()
#     139 if choice == "1":
#     140     list_products()
#
# File ~\Desktop\KursMaterial\.venv\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~\Desktop\KursMaterial\.venv\Lib\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### Aufgabe 2:
# Amplíe la tabla con una entrada "stock."
#
# Convierta su catálogo de productos en un pequeño sistema de gestión de mercancías en el que usted puede ampliar o reducir las existencias.

# %%
# Ihr Code HIER!!!
# Out:
# Spalte 'stock' wurde zur Tabelle 'products' hinzugefügt.

# %% [markdown]
# ### Aufgabe 3:
# Escriba un pequeño menú basado en consolas para que su programa sea cómodo de usar. También debe comprobar si existe la base de datos necesaria al iniciar el programa. Si no lo hace, debe crear una base de bases de datos adecuada.

# %%
# Ihr Code HIER!!!

# %% [markdown]
# <img style="float: center;" src="img/wbs-logo.jpg">
#
# ### Ilustraciones y fuentes
# https://de.wikipedia.org/wiki/Python_(Idioma de programación) El logotipo de Pythan es una marca registrada de la Fundación de Software de Pyothon Todos los logotipos publicados en este sitio web, así como marcas comerciales, productos y marcas registradas, son propiedad de sus respectivas empresas © WBS TRAINING AG • Todos los derechos reservados
#
# ### Nutzungsrechte:
# El uso de esta documentación está autorizado exclusivamente para fines de formación de WBS TRAINING AG. La transferencia a terceros, incluso en parte, así como la reproducción y difusión de todo tipo (procedimientos electrónicos y de otro tipo), incluidas las traducciones, sólo se permite con el consentimiento previo por escrito del titular del derecho.
#
# ### Herausgeber:
#
# WBS TRAINING AG
# Lorenzweg 5
# 12099 Berlin
#
# ### Haftungsausschluss:
# Todos los contenidos son correctos y están completamente investigados y compilados con el máximo cuidado para el documento de formación. Nos esforzamos por actualizar toda la información y los datos en curso. Sin embargo, pueden producirse errores (por ejemplo, desviaciones del hardware y del software descritos mediante actualizaciones a corto plazo) para que no podamos garantizar la plena conformidad, exactitud y actualidad. Los consejos de nuestros usuarios se siguen de forma coherente.
